# %%
import matplotlib.pyplot as plt
import numpy as np
import pyana

# %%
path = '/dat/milic/snapi_synth_cube/'

# %%
wlv_file = path + 'lgrid_momo.dat'

# %%
ll_momo = np.loadtxt(wlv_file,unpack=True, skiprows=1)

# %%
ll_momo
# Out:
# array([4981.5  , 4981.505, 4981.51 , 4981.515, 4981.52 , 4981.525,
#        4981.53 , 4981.535, 4981.54 , 4981.545, 4981.55 , 4981.555,
#        4981.56 , 4981.565, 4981.57 , 4981.575, 4981.58 , 4981.585,
#        4981.59 , 4981.595, 4981.6  , 4981.605, 4981.61 , 4981.615,
#        4981.62 , 4981.625, 4981.63 , 4981.635, 4981.64 , 4981.645,
#        4981.65 , 4981.655, 4981.66 , 4981.665, 4981.67 , 4981.675,
#        4981.68 , 4981.685, 4981.69 , 4981.695, 4981.7  , 4981.705,
#        4981.71 , 4981.715, 4981.72 , 4981.725, 4981.73 , 4981.735,
#        4981.74 , 4981.745, 4981.75 , 4981.755, 4981.76 , 4981.765,
#        4981.77 , 4981.775, 4981.78 , 4981.785, 4981.79 , 4981.795,
#        4981.8  , 4981.805, 4981.81 , 4981.815, 4981.82 , 4981.825,
#        4981.83 , 4981.835, 4981.84 , 4981.845, 4981.85 , 4981.855,
#        4981.86 , 4981.865, 4981.87 , 4981.875, 4981.88 , 4981.885,
#        4981.89 , 4981.895, 4981.9  , 4981.905, 4981.91 , 4981.915,
# ...

# %%
ll_momo.shape
# Out:
# (802,)

# %%
stokescube = path + 'loc_dyn_32_32_16_0_momo.f0'
